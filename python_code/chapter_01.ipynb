# %%
# Chapter 01 Exercises
## Your Name Here
## Date

# %% [markdown]
# __Important Note 01:__ These homework assignments are meant help you practice and understand __both__ Macroeconomic Theory and Introductory Python. For the first few assignments, the only code you will be asked to create yourself are from topics covered in the _Intro to Python for Data Science_ course on Data Camp. All other python modules are meant to demonstrate a concept and only run. Eventually, the homework assignments will require your to write your own python code, please keep this code so you can refer back to it later on.

# %% [markdown]
# __Important Note 02:__ While these problems are taken from the book, some of them will be altered to be able to teach a Python concept, so it is important you read the questions from this assignment and complete what is asked of you. If the question is not actually typed into the assignment then you may refer to the book directly.

# %%
# Libraries you will need for this assignment# Libra 
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3) Country snapshots
#
# ### Your Answers Here:
#
# __(a):__
#
# __(b):__
#
# __(c):__
#
# __(d):__
#
# __(e):__

# %% [markdown]
# ## 4) Making graphics with Python:
#
# Use the [snapshots.pdf](http://web.stanford.edu/~chadj/snapshots.pdf) file, together with its hyperlinks to the underlying data. Use this python notebook to complete the following:
#
# __(a)__ Make a plot of per capita GDP (in dollars) for the years 1950 to 2014 for a country of your choice. Label the x-axis "year" and the y-axis "per capita GDP." [Click here for a list of the country codes](http://web.stanford.edu/~chadj/countrycodes6.3) Write a small description of the plot you create.
#
# __(b)__ Make a plot of per capita GDP relative to the United States (US = 100) for the years 1950 to 2014 that includes the United States and three other countries of your choice, all on the same graph. Be sure to label the lines on the graph in some informative way so that each line can be associated with its country. Write a small description of the plot you create.

# %% [markdown]
# ### Solution Part (a)
# Run the code below, only changing what is asked in the comments.

# %%
# Determine what country's per capita GDP you'd like to graph
# Make sure the country code is in single quotes (ex: 'USA')
country_code = 'USA'

# Read in the data
# *DO NOT CHANGE THIS CODE*
percap_gdp = (pd.read_csv('https://raw.githubusercontent.com/dylanjm/econ_381_development/master/data/final_gdp_data.csv')
              .query('country in @country_code'))

# %%
# Now let's create the plot
# All you need to do is run this code!
fig, ax = plt.subplots()
ax.plot(percap_gdp['year'], percap_gdp['y_pop'])

# Change the title of your graphic to fit with whatever country you chose!
ax.set(xlabel='Year', ylabel='per Capita GDP',
       title='United States per capita GDP 1950-2014')
ax.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### Solution Part (b)
# Run the code below, only changing what is asked in the comments.

# %%
# Insert your 3 countries you'd like to compare to the USA in an array
# Please ensure you keep 'USA' included.
three_countries = ['ARM','CAN','RUS','USA']

# Loop through the three countries and append it to the USA dataset
# *DO NOT CHANGE THIS CODE*
percap_gdp = (pd.read_csv('https://raw.githubusercontent.com/dylanjm/econ_381_development/master/data/final_gdp_data.csv')
              .query("country in @three_countries"))

# %%
# Run this code
# Please note, you are not required to know this section of code just yet.
fig, ax = plt.subplots()
for i in three_countries:
    plot_dat = percap_gdp.query("country == @i")
    ax.plot(plot_dat['year'], plot_dat['y_pop_us_100'], label = i)

# Now let's create the plot
# All you need to do is run this code
# Study this code to see how it sets up the legend, grid, and labels
ax.set(xlabel='Year', 
       ylabel='per Capita GDP (U.S. = 100)',
       title='United States per capita GDP Relative to ' + str(three_countries) + ' 1950-2014')
ax.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## 6) The labor market model (II):
#
# ### Your Answers Below:
#
# __(a):__
#
# __(b):__
#
# __(c):__
#
# __(d):__
#
# __(e):__
